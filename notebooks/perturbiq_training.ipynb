# %% [markdown]
# <a href="https://colab.research.google.com/github/vborra09/perturbiq/blob/main/perturbiq_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"GPU available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
    print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    print("No GPU found - check runtime type")
# Out:
# PyTorch version: 2.10.0+cpu
# GPU available: False
# No GPU found - check runtime type

# %%
import os

if not os.path.exists('/content/perturbiq'):
    # !git clone https://github.com/vborra09/perturbiq.git /content/perturbiq
    print("Repo cloned successfully")
else:
    # !git -C /content/perturbiq pull
    print("Repo updated successfully")

os.chdir('/content/perturbiq')
# !pwd
# !ls
# Out:
# Cloning into '/content/perturbiq'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 31 (delta 6), reused 26 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (31/31), 8.51 KiB | 2.83 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# Repo cloned successfully
# /content/perturbiq
# api		docs	  infra    notebooks	   README.md	     sdk-r
# DECISIONS.md	frontend  LICENSE  pipelines	   requirements.txt  tests
# dev-journal.md	graph	  ml	   pyproject.toml  sdk

# %%
# Install project-specific dependencies
# !pip install -q scanpy==1.10.1 anndata==0.10.8 leidenalg==0.10.2 gseapy==1.1.3
# !pip install -q torch_geometric==2.5.3

print("Dependencies installed")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.4/124.4 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 37.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.0/553.0 kB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.0 MB/s eta 0:00:00
# Dependencies installed

# %%
# !pip install -q scanpy==1.10.1 anndata==0.10.8 leidenalg==0.10.2 gseapy==1.1.3

# !pip install -q torch_geometric==2.5.3

print("Core dependencies installed")
# Out:
# Core dependencies installed

# %%
import torch
import scanpy as sc
import anndata
import torch_geometric

print(f"PyTorch:         {torch.__version__}")
print(f"Scanpy:          {sc.__version__}")
print(f"AnnData:         {anndata.__version__}")
print(f"PyG:             {torch_geometric.__version__}")
print(f"CPU available:   True")
print(f"GPU available:   {torch.cuda.is_available()}")

print("\n✓ Colab environment ready")
# Out:
# PyTorch:         2.10.0+cpu
# Scanpy:          1.10.1
# AnnData:         0.10.8
# PyG:             2.5.3
# CPU available:   True
# GPU available:   False
#
# ✓ Colab environment ready
